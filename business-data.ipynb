# %%
import pandas as pd

# %%
business_data = pd.read_csv("annual-enterprise-survey-2023-financial-year-provisional.csv")

# %%
business_data
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
business_columns = business_data.columns

# %%
business_columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
business_data.index
# Out:
# RangeIndex(start=0, stop=50985, step=1)

# %%
business_data
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
business_data.sum()
# Out:
# Year                                                                   102887730
# Industry_aggregation_NZSIOC    Level 1Level 1Level 1Level 1Level 1Level 1Leve...
# Industry_code_NZSIOC           9999999999999999999999999999999999999999999999...
# Industry_name_NZSIOC           All industriesAll industriesAll industriesAll ...
# Units                          Dollars (millions)Dollars (millions)Dollars (m...
# Variable_code                  H01H04H05H07H08H09H10H11H12H13H14H19H20H21H22H...
# Variable_name                  Total incomeSales, government funding, grants ...
# Variable_category              Financial performanceFinancial performanceFina...
# Value                          9309958216308435425010832964552677426308141476...
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# dtype: object

# %%
business_data.describe()
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000
